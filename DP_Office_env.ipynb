# %%
import numpy as np
import gym
import random

# %%
# Solving policy evaluation using dynamic programming

states = [0,1,2,3,4,5,6,7,8]
actions = [0,1,2,3,4,5]

P = np.zeros((9, 6, 9))  
R = np.zeros((9, 6, 9))  

P[0,4,0] = 1.0
P[1,4,1] = 1.0
P[3,4,3] = 1.0
P[4,4,4] = 1.0
P[5,4,5] = 1.0
P[6,4,6] = 1.0
P[7,4,7] = 1.0
P[8,4,8] = 1.0
P[2,5,2] = 1.0


R[0,4,0] = 5
R[0,5,0] = -10
R[1,4,1] = 5
R[1,5,1] = -10
R[8,4,8] = 5
R[8,5,8] = -10
R[2,5,2] = 50
R[3,4,3] = 5
R[3,5,3] = -10
R[4,4,4] = 5
R[4,5,4] = -10
R[5,4,5] = 5
R[5,5,5] = -10
R[6,4,6] = 5
R[6,5,6] = -10
R[7,4,7] = 5
R[7,5,7] = -10


gamma = 0.9

policy = [0 for s in range(9)]
V = np.zeros(9)

print("Initial policy", policy)



iterations = 0
delta = 0
theta = 0.000001
while delta < theta:
    iterations += 1
    for s in range(9):
        V[s] = sum([P[s,policy[s],s1] * (R[s,policy[s],s1] + gamma*V[s1]) for s1 in range(9)])

    for s in range(9):
        q_best = V[s]
        for a in range(6):
            q_sa = sum([P[s, a, s1] * (R[s, a, s1] + gamma * V[s1]) for s1 in range(9)])
            if q_sa > q_best:
                print("State", s, ": q_selected_action", q_sa, "q_best_action", q_best)
                policy[s] = a
                q_best = q_sa
                delta = max(delta, np.abs(v - V[s]))
    print("Iterations:", iterations)

print("Optimal policy")
print(policy)
print(V)
# Out:
# Initial policy [0, 0, 0, 0, 0, 0, 0, 0, 0]
# State 0 : q_selected_action 5.0 q_best_action 0.0
# State 1 : q_selected_action 5.0 q_best_action 0.0
# State 2 : q_selected_action 50.0 q_best_action 0.0
# State 3 : q_selected_action 5.0 q_best_action 0.0
# State 4 : q_selected_action 5.0 q_best_action 0.0
# State 5 : q_selected_action 5.0 q_best_action 0.0
# State 6 : q_selected_action 5.0 q_best_action 0.0
# State 7 : q_selected_action 5.0 q_best_action 0.0
# State 8 : q_selected_action 5.0 q_best_action 0.0
# Iterations: 1
# State 0 : q_selected_action 9.5 q_best_action 5.0
# State 1 : q_selected_action 9.5 q_best_action 5.0
# State 2 : q_selected_action 95.0 q_best_action 50.0
# State 3 : q_selected_action 9.5 q_best_action 5.0
# State 4 : q_selected_action 9.5 q_best_action 5.0
# State 5 : q_selected_action 9.5 q_best_action 5.0
# State 6 : q_selected_action 9.5 q_best_action 5.0
# State 7 : q_selected_action 9.5 q_best_action 5.0
# State 8 : q_selected_action 9.5 q_best_action 5.0
# Iterations: 2
# Optimal policy
# [4, 4, 5, 4, 4, 4, 4, 4, 4]
# [ 5.  5. 50.  5.  5.  5.  5.  5.  5.]

# %%
# Solving policy iteration using MDP

states = [0,1,2,3,4,5,6,7,8]
actions = [0,1,2,3,4,5]

P = np.zeros((9, 6, 9))  
R = np.zeros((9, 6, 9))  

P[0,4,0] = 1.0
P[1,4,1] = 1.0
P[3,4,3] = 1.0
P[4,4,4] = 1.0
P[5,4,5] = 1.0
P[6,4,6] = 1.0
P[7,4,7] = 1.0
P[8,4,8] = 1.0
P[2,5,2] = 1.0


R[0,4,0] = 5
R[0,5,0] = -10
R[1,4,1] = 5
R[1,5,1] = -10
R[8,4,8] = 5
R[8,5,8] = -10
R[2,5,2] = 50
R[3,4,3] = 5
R[3,5,3] = -10
R[4,4,4] = 5
R[4,5,4] = -10
R[5,4,5] = 5
R[5,5,5] = -10
R[6,4,6] = 5
R[6,5,6] = -10
R[7,4,7] = 5
R[7,5,7] = -10


gamma = 0.9

policy = [0 for s in range(9)]
V = np.zeros(9)

print("Initial policy", policy)


is_value_changed = True
iterations = 0
while is_value_changed:
    is_value_changed = False
    iterations += 1
    for s in range(9):
        V[s] = sum([P[s,policy[s],s1] * (R[s,policy[s],s1] + gamma*V[s1]) for s1 in range(9)])

    for s in range(9):
        q_best = V[s]
        for a in range(6):
            q_sa = sum([P[s, a, s1] * (R[s, a, s1] + gamma * V[s1]) for s1 in range(9)])
            if q_sa > q_best:
                print("State", s, ": q_selected_action", q_sa, "q_best_action", q_best)
                policy[s] = a
                q_best = q_sa
                is_value_changed = True

    print("Iterations:", iterations)

print("Optimal policy")
print(policy)
print(V)
# Out:
# Initial policy [0, 0, 0, 0, 0, 0, 0, 0, 0]
# State 0 : q_selected_action 5.0 q_best_action 0.0
# State 1 : q_selected_action 5.0 q_best_action 0.0
# State 2 : q_selected_action 50.0 q_best_action 0.0
# State 3 : q_selected_action 5.0 q_best_action 0.0
# State 4 : q_selected_action 5.0 q_best_action 0.0
# State 5 : q_selected_action 5.0 q_best_action 0.0
# State 6 : q_selected_action 5.0 q_best_action 0.0
# State 7 : q_selected_action 5.0 q_best_action 0.0
# State 8 : q_selected_action 5.0 q_best_action 0.0
# Iterations: 1
# State 0 : q_selected_action 9.5 q_best_action 5.0
# State 1 : q_selected_action 9.5 q_best_action 5.0
# State 2 : q_selected_action 95.0 q_best_action 50.0
# State 3 : q_selected_action 9.5 q_best_action 5.0
# State 4 : q_selected_action 9.5 q_best_action 5.0
# State 5 : q_selected_action 9.5 q_best_action 5.0
# State 6 : q_selected_action 9.5 q_best_action 5.0
# State 7 : q_selected_action 9.5 q_best_action 5.0
# State 8 : q_selected_action 9.5 q_best_action 5.0
# Iterations: 2
# State 0 : q_selected_action 13.55 q_best_action 9.5
# State 1 : q_selected_action 13.55 q_best_action 9.5
# State 2 : q_selected_action 135.5 q_best_action 95.0
# State 3 : q_selected_action 13.55 q_best_action 9.5
# State 4 : q_selected_action 13.55 q_best_action 9.5
# State 5 : q_selected_action 13.55 q_best_action 9.5
# State 6 : q_selected_action 13.55 q_best_action 9.5
# State 7 : q_selected_action 13.55 q_best_action 9.5
# State 8 : q_selected_action 13.55 q_best_action 9.5
# Iterations: 3
# State 0 : q_selected_action 17.195 q_best_action 13.55
# State 1 : q_selected_action 17.195 q_best_action 13.55
# State 2 : q_selected_action 171.95 q_best_action 135.5
# State 3 : q_selected_action 17.195 q_best_action 13.55
# State 4 : q_selected_action 17.195 q_best_action 13.55
# State 5 : q_selected_action 17.195 q_best_action 13.55
# State 6 : q_selected_action 17.195 q_best_action 13.55
# State 7 : q_selected_action 17.195 q_best_action 13.55
# State 8 : q_selected_action 17.195 q_best_action 13.55
# Iterations: 4
# State 0 : q_selected_action 20.4755 q_best_action 17.195
# State 1 : q_selected_action 20.4755 q_best_action 17.195
# State 2 : q_selected_action 204.755 q_best_action 171.95
# State 3 : q_selected_action 20.4755 q_best_action 17.195
# State 4 : q_selected_action 20.4755 q_best_action 17.195
# State 5 : q_selected_action 20.4755 q_best_action 17.195
# State 6 : q_selected_action 20.4755 q_best_action 17.195
# State 7 : q_selected_action 20.4755 q_best_action 17.195
# State 8 : q_selected_action 20.4755 q_best_action 17.195
# Iterations: 5
# State 0 : q_selected_action 23.42795 q_best_action 20.4755
# State 1 : q_selected_action 23.42795 q_best_action 20.4755
# State 2 : q_selected_action 234.2795 q_best_action 204.755
# State 3 : q_selected_action 23.42795 q_best_action 20.4755
# State 4 : q_selected_action 23.42795 q_best_action 20.4755
# State 5 : q_selected_action 23.42795 q_best_action 20.4755
# State 6 : q_selected_action 23.42795 q_best_action 20.4755
# State 7 : q_selected_action 23.42795 q_best_action 20.4755
# State 8 : q_selected_action 23.42795 q_best_action 20.4755
# Iterations: 6
# State 0 : q_selected_action 26.085155 q_best_action 23.42795
# State 1 : q_selected_action 26.085155 q_best_action 23.42795
# State 2 : q_selected_action 260.85155 q_best_action 234.2795
# State 3 : q_selected_action 26.085155 q_best_action 23.42795
# State 4 : q_selected_action 26.085155 q_best_action 23.42795
# State 5 : q_selected_action 26.085155 q_best_action 23.42795
# State 6 : q_selected_action 26.085155 q_best_action 23.42795
# State 7 : q_selected_action 26.085155 q_best_action 23.42795
# State 8 : q_selected_action 26.085155 q_best_action 23.42795
# Iterations: 7
# State 0 : q_selected_action 28.4766395 q_best_action 26.085155
# State 1 : q_selected_action 28.4766395 q_best_action 26.085155
# State 2 : q_selected_action 284.766395 q_best_action 260.85155
# State 3 : q_selected_action 28.4766395 q_best_action 26.085155
# State 4 : q_selected_action 28.4766395 q_best_action 26.085155
# State 5 : q_selected_action 28.4766395 q_best_action 26.085155
# State 6 : q_selected_action 28.4766395 q_best_action 26.085155
# State 7 : q_selected_action 28.4766395 q_best_action 26.085155
# State 8 : q_selected_action 28.4766395 q_best_action 26.085155
# Iterations: 8
# State 0 : q_selected_action 30.62897555 q_best_action 28.4766395
# State 1 : q_selected_action 30.62897555 q_best_action 28.4766395
# State 2 : q_selected_action 306.2897555 q_best_action 284.766395
# State 3 : q_selected_action 30.62897555 q_best_action 28.4766395
# State 4 : q_selected_action 30.62897555 q_best_action 28.4766395
# State 5 : q_selected_action 30.62897555 q_best_action 28.4766395
# State 6 : q_selected_action 30.62897555 q_best_action 28.4766395
# State 7 : q_selected_action 30.62897555 q_best_action 28.4766395
# State 8 : q_selected_action 30.62897555 q_best_action 28.4766395
# Iterations: 9
# State 0 : q_selected_action 32.566077995 q_best_action 30.62897555
# State 1 : q_selected_action 32.566077995 q_best_action 30.62897555
# State 2 : q_selected_action 325.66077995 q_best_action 306.2897555
# State 3 : q_selected_action 32.566077995 q_best_action 30.62897555
# State 4 : q_selected_action 32.566077995 q_best_action 30.62897555
# State 5 : q_selected_action 32.566077995 q_best_action 30.62897555
# State 6 : q_selected_action 32.566077995 q_best_action 30.62897555
# State 7 : q_selected_action 32.566077995 q_best_action 30.62897555
# State 8 : q_selected_action 32.566077995 q_best_action 30.62897555
# Iterations: 10
# State 0 : q_selected_action 34.3094701955 q_best_action 32.566077995
# State 1 : q_selected_action 34.3094701955 q_best_action 32.566077995
# State 2 : q_selected_action 343.094701955 q_best_action 325.66077995
# State 3 : q_selected_action 34.3094701955 q_best_action 32.566077995
# State 4 : q_selected_action 34.3094701955 q_best_action 32.566077995
# State 5 : q_selected_action 34.3094701955 q_best_action 32.566077995
# State 6 : q_selected_action 34.3094701955 q_best_action 32.566077995
# State 7 : q_selected_action 34.3094701955 q_best_action 32.566077995
# State 8 : q_selected_action 34.3094701955 q_best_action 32.566077995
# Iterations: 11
# State 0 : q_selected_action 35.878523175949994 q_best_action 34.3094701955
# State 1 : q_selected_action 35.878523175949994 q_best_action 34.3094701955
# State 2 : q_selected_action 358.7852317595 q_best_action 343.094701955
# State 3 : q_selected_action 35.878523175949994 q_best_action 34.3094701955
# State 4 : q_selected_action 35.878523175949994 q_best_action 34.3094701955
# State 5 : q_selected_action 35.878523175949994 q_best_action 34.3094701955
# State 6 : q_selected_action 35.878523175949994 q_best_action 34.3094701955
# State 7 : q_selected_action 35.878523175949994 q_best_action 34.3094701955
# State 8 : q_selected_action 35.878523175949994 q_best_action 34.3094701955
# Iterations: 12
# State 0 : q_selected_action 37.29067085835499 q_best_action 35.878523175949994
# State 1 : q_selected_action 37.29067085835499 q_best_action 35.878523175949994
# State 2 : q_selected_action 372.90670858355 q_best_action 358.7852317595
# State 3 : q_selected_action 37.29067085835499 q_best_action 35.878523175949994
# State 4 : q_selected_action 37.29067085835499 q_best_action 35.878523175949994
# State 5 : q_selected_action 37.29067085835499 q_best_action 35.878523175949994
# State 6 : q_selected_action 37.29067085835499 q_best_action 35.878523175949994
# State 7 : q_selected_action 37.29067085835499 q_best_action 35.878523175949994
# State 8 : q_selected_action 37.29067085835499 q_best_action 35.878523175949994
# Iterations: 13
# State 0 : q_selected_action 38.5616037725195 q_best_action 37.29067085835499
# State 1 : q_selected_action 38.5616037725195 q_best_action 37.29067085835499
# State 2 : q_selected_action 385.61603772519504 q_best_action 372.90670858355
# State 3 : q_selected_action 38.5616037725195 q_best_action 37.29067085835499
# State 4 : q_selected_action 38.5616037725195 q_best_action 37.29067085835499
# State 5 : q_selected_action 38.5616037725195 q_best_action 37.29067085835499
# State 6 : q_selected_action 38.5616037725195 q_best_action 37.29067085835499
# State 7 : q_selected_action 38.5616037725195 q_best_action 37.29067085835499
# State 8 : q_selected_action 38.5616037725195 q_best_action 37.29067085835499
# Iterations: 14
# State 0 : q_selected_action 39.70544339526755 q_best_action 38.5616037725195
# State 1 : q_selected_action 39.70544339526755 q_best_action 38.5616037725195
# State 2 : q_selected_action 397.05443395267554 q_best_action 385.61603772519504
# State 3 : q_selected_action 39.70544339526755 q_best_action 38.5616037725195
# State 4 : q_selected_action 39.70544339526755 q_best_action 38.5616037725195
# State 5 : q_selected_action 39.70544339526755 q_best_action 38.5616037725195
# State 6 : q_selected_action 39.70544339526755 q_best_action 38.5616037725195
# State 7 : q_selected_action 39.70544339526755 q_best_action 38.5616037725195
# State 8 : q_selected_action 39.70544339526755 q_best_action 38.5616037725195
# Iterations: 15
# State 0 : q_selected_action 40.7348990557408 q_best_action 39.70544339526755
# State 1 : q_selected_action 40.7348990557408 q_best_action 39.70544339526755
# State 2 : q_selected_action 407.348990557408 q_best_action 397.05443395267554
# State 3 : q_selected_action 40.7348990557408 q_best_action 39.70544339526755
# State 4 : q_selected_action 40.7348990557408 q_best_action 39.70544339526755
# State 5 : q_selected_action 40.7348990557408 q_best_action 39.70544339526755
# State 6 : q_selected_action 40.7348990557408 q_best_action 39.70544339526755
# State 7 : q_selected_action 40.7348990557408 q_best_action 39.70544339526755
# State 8 : q_selected_action 40.7348990557408 q_best_action 39.70544339526755
# Iterations: 16
# State 0 : q_selected_action 41.66140915016672 q_best_action 40.7348990557408
# State 1 : q_selected_action 41.66140915016672 q_best_action 40.7348990557408
# State 2 : q_selected_action 416.6140915016672 q_best_action 407.348990557408
# State 3 : q_selected_action 41.66140915016672 q_best_action 40.7348990557408
# State 4 : q_selected_action 41.66140915016672 q_best_action 40.7348990557408
# State 5 : q_selected_action 41.66140915016672 q_best_action 40.7348990557408
# State 6 : q_selected_action 41.66140915016672 q_best_action 40.7348990557408
# State 7 : q_selected_action 41.66140915016672 q_best_action 40.7348990557408
# State 8 : q_selected_action 41.66140915016672 q_best_action 40.7348990557408
# Iterations: 17
# State 0 : q_selected_action 42.49526823515005 q_best_action 41.66140915016672
# State 1 : q_selected_action 42.49526823515005 q_best_action 41.66140915016672
# State 2 : q_selected_action 424.95268235150047 q_best_action 416.6140915016672
# State 3 : q_selected_action 42.49526823515005 q_best_action 41.66140915016672
# State 4 : q_selected_action 42.49526823515005 q_best_action 41.66140915016672
# State 5 : q_selected_action 42.49526823515005 q_best_action 41.66140915016672
# State 6 : q_selected_action 42.49526823515005 q_best_action 41.66140915016672
# State 7 : q_selected_action 42.49526823515005 q_best_action 41.66140915016672
# State 8 : q_selected_action 42.49526823515005 q_best_action 41.66140915016672
# Iterations: 18
# State 0 : q_selected_action 43.245741411635045 q_best_action 42.49526823515005
# State 1 : q_selected_action 43.245741411635045 q_best_action 42.49526823515005
# State 2 : q_selected_action 432.45741411635044 q_best_action 424.95268235150047
# State 3 : q_selected_action 43.245741411635045 q_best_action 42.49526823515005
# State 4 : q_selected_action 43.245741411635045 q_best_action 42.49526823515005
# State 5 : q_selected_action 43.245741411635045 q_best_action 42.49526823515005
# State 6 : q_selected_action 43.245741411635045 q_best_action 42.49526823515005
# State 7 : q_selected_action 43.245741411635045 q_best_action 42.49526823515005
# State 8 : q_selected_action 43.245741411635045 q_best_action 42.49526823515005
# Iterations: 19
# State 0 : q_selected_action 43.92116727047154 q_best_action 43.245741411635045
# State 1 : q_selected_action 43.92116727047154 q_best_action 43.245741411635045
# State 2 : q_selected_action 439.2116727047154 q_best_action 432.45741411635044
# State 3 : q_selected_action 43.92116727047154 q_best_action 43.245741411635045
# State 4 : q_selected_action 43.92116727047154 q_best_action 43.245741411635045
# State 5 : q_selected_action 43.92116727047154 q_best_action 43.245741411635045
# State 6 : q_selected_action 43.92116727047154 q_best_action 43.245741411635045
# State 7 : q_selected_action 43.92116727047154 q_best_action 43.245741411635045
# State 8 : q_selected_action 43.92116727047154 q_best_action 43.245741411635045
# Iterations: 20
# State 0 : q_selected_action 44.52905054342439 q_best_action 43.92116727047154
# State 1 : q_selected_action 44.52905054342439 q_best_action 43.92116727047154
# State 2 : q_selected_action 445.29050543424387 q_best_action 439.2116727047154
# State 3 : q_selected_action 44.52905054342439 q_best_action 43.92116727047154
# State 4 : q_selected_action 44.52905054342439 q_best_action 43.92116727047154
# State 5 : q_selected_action 44.52905054342439 q_best_action 43.92116727047154
# State 6 : q_selected_action 44.52905054342439 q_best_action 43.92116727047154
# State 7 : q_selected_action 44.52905054342439 q_best_action 43.92116727047154
# State 8 : q_selected_action 44.52905054342439 q_best_action 43.92116727047154
# Iterations: 21
# State 0 : q_selected_action 45.07614548908195 q_best_action 44.52905054342439
# State 1 : q_selected_action 45.07614548908195 q_best_action 44.52905054342439
# State 2 : q_selected_action 450.7614548908195 q_best_action 445.29050543424387
# State 3 : q_selected_action 45.07614548908195 q_best_action 44.52905054342439
# State 4 : q_selected_action 45.07614548908195 q_best_action 44.52905054342439
# State 5 : q_selected_action 45.07614548908195 q_best_action 44.52905054342439
# State 6 : q_selected_action 45.07614548908195 q_best_action 44.52905054342439
# State 7 : q_selected_action 45.07614548908195 q_best_action 44.52905054342439
# State 8 : q_selected_action 45.07614548908195 q_best_action 44.52905054342439
# Iterations: 22
# State 0 : q_selected_action 45.56853094017376 q_best_action 45.07614548908195
# State 1 : q_selected_action 45.56853094017376 q_best_action 45.07614548908195
# State 2 : q_selected_action 455.6853094017375 q_best_action 450.7614548908195
# State 3 : q_selected_action 45.56853094017376 q_best_action 45.07614548908195
# State 4 : q_selected_action 45.56853094017376 q_best_action 45.07614548908195
# State 5 : q_selected_action 45.56853094017376 q_best_action 45.07614548908195
# State 6 : q_selected_action 45.56853094017376 q_best_action 45.07614548908195
# State 7 : q_selected_action 45.56853094017376 q_best_action 45.07614548908195
# State 8 : q_selected_action 45.56853094017376 q_best_action 45.07614548908195
# Iterations: 23
# State 0 : q_selected_action 46.01167784615638 q_best_action 45.56853094017376
# State 1 : q_selected_action 46.01167784615638 q_best_action 45.56853094017376
# State 2 : q_selected_action 460.1167784615638 q_best_action 455.6853094017375
# State 3 : q_selected_action 46.01167784615638 q_best_action 45.56853094017376
# State 4 : q_selected_action 46.01167784615638 q_best_action 45.56853094017376
# State 5 : q_selected_action 46.01167784615638 q_best_action 45.56853094017376
# State 6 : q_selected_action 46.01167784615638 q_best_action 45.56853094017376
# State 7 : q_selected_action 46.01167784615638 q_best_action 45.56853094017376
# State 8 : q_selected_action 46.01167784615638 q_best_action 45.56853094017376
# Iterations: 24
# State 0 : q_selected_action 46.41051006154074 q_best_action 46.01167784615638
# State 1 : q_selected_action 46.41051006154074 q_best_action 46.01167784615638
# State 2 : q_selected_action 464.1051006154074 q_best_action 460.1167784615638
# State 3 : q_selected_action 46.41051006154074 q_best_action 46.01167784615638
# State 4 : q_selected_action 46.41051006154074 q_best_action 46.01167784615638
# State 5 : q_selected_action 46.41051006154074 q_best_action 46.01167784615638
# State 6 : q_selected_action 46.41051006154074 q_best_action 46.01167784615638
# State 7 : q_selected_action 46.41051006154074 q_best_action 46.01167784615638
# State 8 : q_selected_action 46.41051006154074 q_best_action 46.01167784615638
# Iterations: 25
# State 0 : q_selected_action 46.76945905538667 q_best_action 46.41051006154074
# State 1 : q_selected_action 46.76945905538667 q_best_action 46.41051006154074
# State 2 : q_selected_action 467.6945905538667 q_best_action 464.1051006154074
# State 3 : q_selected_action 46.76945905538667 q_best_action 46.41051006154074
# State 4 : q_selected_action 46.76945905538667 q_best_action 46.41051006154074
# State 5 : q_selected_action 46.76945905538667 q_best_action 46.41051006154074
# State 6 : q_selected_action 46.76945905538667 q_best_action 46.41051006154074
# State 7 : q_selected_action 46.76945905538667 q_best_action 46.41051006154074
# State 8 : q_selected_action 46.76945905538667 q_best_action 46.41051006154074
# Iterations: 26
# State 0 : q_selected_action 47.092513149848 q_best_action 46.76945905538667
# State 1 : q_selected_action 47.092513149848 q_best_action 46.76945905538667
# State 2 : q_selected_action 470.92513149848 q_best_action 467.6945905538667
# State 3 : q_selected_action 47.092513149848 q_best_action 46.76945905538667
# State 4 : q_selected_action 47.092513149848 q_best_action 46.76945905538667
# State 5 : q_selected_action 47.092513149848 q_best_action 46.76945905538667
# State 6 : q_selected_action 47.092513149848 q_best_action 46.76945905538667
# State 7 : q_selected_action 47.092513149848 q_best_action 46.76945905538667
# State 8 : q_selected_action 47.092513149848 q_best_action 46.76945905538667
# Iterations: 27
# State 0 : q_selected_action 47.383261834863205 q_best_action 47.092513149848
# State 1 : q_selected_action 47.383261834863205 q_best_action 47.092513149848
# State 2 : q_selected_action 473.832618348632 q_best_action 470.92513149848
# State 3 : q_selected_action 47.383261834863205 q_best_action 47.092513149848
# State 4 : q_selected_action 47.383261834863205 q_best_action 47.092513149848
# State 5 : q_selected_action 47.383261834863205 q_best_action 47.092513149848
# State 6 : q_selected_action 47.383261834863205 q_best_action 47.092513149848
# State 7 : q_selected_action 47.383261834863205 q_best_action 47.092513149848
# State 8 : q_selected_action 47.383261834863205 q_best_action 47.092513149848
# Iterations: 28
# State 0 : q_selected_action 47.64493565137688 q_best_action 47.383261834863205
# State 1 : q_selected_action 47.64493565137688 q_best_action 47.383261834863205
# State 2 : q_selected_action 476.4493565137688 q_best_action 473.832618348632
# State 3 : q_selected_action 47.64493565137688 q_best_action 47.383261834863205
# State 4 : q_selected_action 47.64493565137688 q_best_action 47.383261834863205
# State 5 : q_selected_action 47.64493565137688 q_best_action 47.383261834863205
# State 6 : q_selected_action 47.64493565137688 q_best_action 47.383261834863205
# State 7 : q_selected_action 47.64493565137688 q_best_action 47.383261834863205
# State 8 : q_selected_action 47.64493565137688 q_best_action 47.383261834863205
# Iterations: 29
# State 0 : q_selected_action 47.8804420862392 q_best_action 47.64493565137688
# State 1 : q_selected_action 47.8804420862392 q_best_action 47.64493565137688
# State 2 : q_selected_action 478.8044208623919 q_best_action 476.4493565137688
# State 3 : q_selected_action 47.8804420862392 q_best_action 47.64493565137688
# State 4 : q_selected_action 47.8804420862392 q_best_action 47.64493565137688
# State 5 : q_selected_action 47.8804420862392 q_best_action 47.64493565137688
# State 6 : q_selected_action 47.8804420862392 q_best_action 47.64493565137688
# State 7 : q_selected_action 47.8804420862392 q_best_action 47.64493565137688
# State 8 : q_selected_action 47.8804420862392 q_best_action 47.64493565137688
# Iterations: 30
# State 0 : q_selected_action 48.092397877615284 q_best_action 47.8804420862392
# State 1 : q_selected_action 48.092397877615284 q_best_action 47.8804420862392
# State 2 : q_selected_action 480.92397877615275 q_best_action 478.8044208623919
# State 3 : q_selected_action 48.092397877615284 q_best_action 47.8804420862392
# State 4 : q_selected_action 48.092397877615284 q_best_action 47.8804420862392
# State 5 : q_selected_action 48.092397877615284 q_best_action 47.8804420862392
# State 6 : q_selected_action 48.092397877615284 q_best_action 47.8804420862392
# State 7 : q_selected_action 48.092397877615284 q_best_action 47.8804420862392
# State 8 : q_selected_action 48.092397877615284 q_best_action 47.8804420862392
# Iterations: 31
# State 0 : q_selected_action 48.28315808985376 q_best_action 48.092397877615284
# State 1 : q_selected_action 48.28315808985376 q_best_action 48.092397877615284
# State 2 : q_selected_action 482.8315808985375 q_best_action 480.92397877615275
# State 3 : q_selected_action 48.28315808985376 q_best_action 48.092397877615284
# State 4 : q_selected_action 48.28315808985376 q_best_action 48.092397877615284
# State 5 : q_selected_action 48.28315808985376 q_best_action 48.092397877615284
# State 6 : q_selected_action 48.28315808985376 q_best_action 48.092397877615284
# State 7 : q_selected_action 48.28315808985376 q_best_action 48.092397877615284
# State 8 : q_selected_action 48.28315808985376 q_best_action 48.092397877615284
# Iterations: 32
# State 0 : q_selected_action 48.454842280868384 q_best_action 48.28315808985376
# State 1 : q_selected_action 48.454842280868384 q_best_action 48.28315808985376
# State 2 : q_selected_action 484.54842280868377 q_best_action 482.8315808985375
# State 3 : q_selected_action 48.454842280868384 q_best_action 48.28315808985376
# State 4 : q_selected_action 48.454842280868384 q_best_action 48.28315808985376
# State 5 : q_selected_action 48.454842280868384 q_best_action 48.28315808985376
# State 6 : q_selected_action 48.454842280868384 q_best_action 48.28315808985376
# State 7 : q_selected_action 48.454842280868384 q_best_action 48.28315808985376
# State 8 : q_selected_action 48.454842280868384 q_best_action 48.28315808985376
# Iterations: 33
# State 0 : q_selected_action 48.609358052781545 q_best_action 48.454842280868384
# State 1 : q_selected_action 48.609358052781545 q_best_action 48.454842280868384
# State 2 : q_selected_action 486.0935805278154 q_best_action 484.54842280868377
# State 3 : q_selected_action 48.609358052781545 q_best_action 48.454842280868384
# State 4 : q_selected_action 48.609358052781545 q_best_action 48.454842280868384
# State 5 : q_selected_action 48.609358052781545 q_best_action 48.454842280868384
# State 6 : q_selected_action 48.609358052781545 q_best_action 48.454842280868384
# State 7 : q_selected_action 48.609358052781545 q_best_action 48.454842280868384
# State 8 : q_selected_action 48.609358052781545 q_best_action 48.454842280868384
# Iterations: 34
# State 0 : q_selected_action 48.74842224750339 q_best_action 48.609358052781545
# State 1 : q_selected_action 48.74842224750339 q_best_action 48.609358052781545
# State 2 : q_selected_action 487.48422247503385 q_best_action 486.0935805278154
# State 3 : q_selected_action 48.74842224750339 q_best_action 48.609358052781545
# State 4 : q_selected_action 48.74842224750339 q_best_action 48.609358052781545
# State 5 : q_selected_action 48.74842224750339 q_best_action 48.609358052781545
# State 6 : q_selected_action 48.74842224750339 q_best_action 48.609358052781545
# State 7 : q_selected_action 48.74842224750339 q_best_action 48.609358052781545
# State 8 : q_selected_action 48.74842224750339 q_best_action 48.609358052781545
# Iterations: 35
# State 0 : q_selected_action 48.87358002275305 q_best_action 48.74842224750339
# State 1 : q_selected_action 48.87358002275305 q_best_action 48.74842224750339
# State 2 : q_selected_action 488.7358002275305 q_best_action 487.48422247503385
# State 3 : q_selected_action 48.87358002275305 q_best_action 48.74842224750339
# State 4 : q_selected_action 48.87358002275305 q_best_action 48.74842224750339
# State 5 : q_selected_action 48.87358002275305 q_best_action 48.74842224750339
# State 6 : q_selected_action 48.87358002275305 q_best_action 48.74842224750339
# State 7 : q_selected_action 48.87358002275305 q_best_action 48.74842224750339
# State 8 : q_selected_action 48.87358002275305 q_best_action 48.74842224750339
# Iterations: 36
# State 0 : q_selected_action 48.98622202047775 q_best_action 48.87358002275305
# State 1 : q_selected_action 48.98622202047775 q_best_action 48.87358002275305
# State 2 : q_selected_action 489.86222020477743 q_best_action 488.7358002275305
# State 3 : q_selected_action 48.98622202047775 q_best_action 48.87358002275305
# State 4 : q_selected_action 48.98622202047775 q_best_action 48.87358002275305
# State 5 : q_selected_action 48.98622202047775 q_best_action 48.87358002275305
# State 6 : q_selected_action 48.98622202047775 q_best_action 48.87358002275305
# State 7 : q_selected_action 48.98622202047775 q_best_action 48.87358002275305
# State 8 : q_selected_action 48.98622202047775 q_best_action 48.87358002275305
# Iterations: 37
# State 0 : q_selected_action 49.08759981842997 q_best_action 48.98622202047775
# State 1 : q_selected_action 49.08759981842997 q_best_action 48.98622202047775
# State 2 : q_selected_action 490.8759981842997 q_best_action 489.86222020477743
# State 3 : q_selected_action 49.08759981842997 q_best_action 48.98622202047775
# State 4 : q_selected_action 49.08759981842997 q_best_action 48.98622202047775
# State 5 : q_selected_action 49.08759981842997 q_best_action 48.98622202047775
# State 6 : q_selected_action 49.08759981842997 q_best_action 48.98622202047775
# State 7 : q_selected_action 49.08759981842997 q_best_action 48.98622202047775
# State 8 : q_selected_action 49.08759981842997 q_best_action 48.98622202047775
# Iterations: 38
# State 0 : q_selected_action 49.178839836586974 q_best_action 49.08759981842997
# State 1 : q_selected_action 49.178839836586974 q_best_action 49.08759981842997
# State 2 : q_selected_action 491.78839836586974 q_best_action 490.8759981842997
# State 3 : q_selected_action 49.178839836586974 q_best_action 49.08759981842997
# State 4 : q_selected_action 49.178839836586974 q_best_action 49.08759981842997
# State 5 : q_selected_action 49.178839836586974 q_best_action 49.08759981842997
# State 6 : q_selected_action 49.178839836586974 q_best_action 49.08759981842997
# State 7 : q_selected_action 49.178839836586974 q_best_action 49.08759981842997
# State 8 : q_selected_action 49.178839836586974 q_best_action 49.08759981842997
# Iterations: 39
# State 0 : q_selected_action 49.26095585292828 q_best_action 49.178839836586974
# State 1 : q_selected_action 49.26095585292828 q_best_action 49.178839836586974
# State 2 : q_selected_action 492.60955852928276 q_best_action 491.78839836586974
# State 3 : q_selected_action 49.26095585292828 q_best_action 49.178839836586974
# State 4 : q_selected_action 49.26095585292828 q_best_action 49.178839836586974
# State 5 : q_selected_action 49.26095585292828 q_best_action 49.178839836586974
# State 6 : q_selected_action 49.26095585292828 q_best_action 49.178839836586974
# State 7 : q_selected_action 49.26095585292828 q_best_action 49.178839836586974
# State 8 : q_selected_action 49.26095585292828 q_best_action 49.178839836586974
# Iterations: 40
# State 0 : q_selected_action 49.33486026763545 q_best_action 49.26095585292828
# State 1 : q_selected_action 49.33486026763545 q_best_action 49.26095585292828
# State 2 : q_selected_action 493.3486026763545 q_best_action 492.60955852928276
# State 3 : q_selected_action 49.33486026763545 q_best_action 49.26095585292828
# State 4 : q_selected_action 49.33486026763545 q_best_action 49.26095585292828
# State 5 : q_selected_action 49.33486026763545 q_best_action 49.26095585292828
# State 6 : q_selected_action 49.33486026763545 q_best_action 49.26095585292828
# State 7 : q_selected_action 49.33486026763545 q_best_action 49.26095585292828
# State 8 : q_selected_action 49.33486026763545 q_best_action 49.26095585292828
# Iterations: 41
# State 0 : q_selected_action 49.4013742408719 q_best_action 49.33486026763545
# State 1 : q_selected_action 49.4013742408719 q_best_action 49.33486026763545
# State 2 : q_selected_action 494.01374240871905 q_best_action 493.3486026763545
# State 3 : q_selected_action 49.4013742408719 q_best_action 49.33486026763545
# State 4 : q_selected_action 49.4013742408719 q_best_action 49.33486026763545
# State 5 : q_selected_action 49.4013742408719 q_best_action 49.33486026763545
# State 6 : q_selected_action 49.4013742408719 q_best_action 49.33486026763545
# State 7 : q_selected_action 49.4013742408719 q_best_action 49.33486026763545
# State 8 : q_selected_action 49.4013742408719 q_best_action 49.33486026763545
# Iterations: 42
# State 0 : q_selected_action 49.46123681678471 q_best_action 49.4013742408719
# State 1 : q_selected_action 49.46123681678471 q_best_action 49.4013742408719
# State 2 : q_selected_action 494.61236816784714 q_best_action 494.01374240871905
# State 3 : q_selected_action 49.46123681678471 q_best_action 49.4013742408719
# State 4 : q_selected_action 49.46123681678471 q_best_action 49.4013742408719
# State 5 : q_selected_action 49.46123681678471 q_best_action 49.4013742408719
# State 6 : q_selected_action 49.46123681678471 q_best_action 49.4013742408719
# State 7 : q_selected_action 49.46123681678471 q_best_action 49.4013742408719
# State 8 : q_selected_action 49.46123681678471 q_best_action 49.4013742408719
# Iterations: 43
# State 0 : q_selected_action 49.51511313510624 q_best_action 49.46123681678471
# State 1 : q_selected_action 49.51511313510624 q_best_action 49.46123681678471
# State 2 : q_selected_action 495.1511313510624 q_best_action 494.61236816784714
# State 3 : q_selected_action 49.51511313510624 q_best_action 49.46123681678471
# State 4 : q_selected_action 49.51511313510624 q_best_action 49.46123681678471
# State 5 : q_selected_action 49.51511313510624 q_best_action 49.46123681678471
# State 6 : q_selected_action 49.51511313510624 q_best_action 49.46123681678471
# State 7 : q_selected_action 49.51511313510624 q_best_action 49.46123681678471
# State 8 : q_selected_action 49.51511313510624 q_best_action 49.46123681678471
# Iterations: 44
# State 0 : q_selected_action 49.56360182159562 q_best_action 49.51511313510624
# State 1 : q_selected_action 49.56360182159562 q_best_action 49.51511313510624
# State 2 : q_selected_action 495.6360182159562 q_best_action 495.1511313510624
# State 3 : q_selected_action 49.56360182159562 q_best_action 49.51511313510624
# State 4 : q_selected_action 49.56360182159562 q_best_action 49.51511313510624
# State 5 : q_selected_action 49.56360182159562 q_best_action 49.51511313510624
# State 6 : q_selected_action 49.56360182159562 q_best_action 49.51511313510624
# State 7 : q_selected_action 49.56360182159562 q_best_action 49.51511313510624
# State 8 : q_selected_action 49.56360182159562 q_best_action 49.51511313510624
# Iterations: 45
# State 0 : q_selected_action 49.607241639436054 q_best_action 49.56360182159562
# State 1 : q_selected_action 49.607241639436054 q_best_action 49.56360182159562
# State 2 : q_selected_action 496.0724163943606 q_best_action 495.6360182159562
# State 3 : q_selected_action 49.607241639436054 q_best_action 49.56360182159562
# State 4 : q_selected_action 49.607241639436054 q_best_action 49.56360182159562
# State 5 : q_selected_action 49.607241639436054 q_best_action 49.56360182159562
# State 6 : q_selected_action 49.607241639436054 q_best_action 49.56360182159562
# State 7 : q_selected_action 49.607241639436054 q_best_action 49.56360182159562
# State 8 : q_selected_action 49.607241639436054 q_best_action 49.56360182159562
# Iterations: 46
# State 0 : q_selected_action 49.64651747549245 q_best_action 49.607241639436054
# State 1 : q_selected_action 49.64651747549245 q_best_action 49.607241639436054
# State 2 : q_selected_action 496.46517475492453 q_best_action 496.0724163943606
# State 3 : q_selected_action 49.64651747549245 q_best_action 49.607241639436054
# State 4 : q_selected_action 49.64651747549245 q_best_action 49.607241639436054
# State 5 : q_selected_action 49.64651747549245 q_best_action 49.607241639436054
# State 6 : q_selected_action 49.64651747549245 q_best_action 49.607241639436054
# State 7 : q_selected_action 49.64651747549245 q_best_action 49.607241639436054
# State 8 : q_selected_action 49.64651747549245 q_best_action 49.607241639436054
# Iterations: 47
# State 0 : q_selected_action 49.681865727943205 q_best_action 49.64651747549245
# State 1 : q_selected_action 49.681865727943205 q_best_action 49.64651747549245
# State 2 : q_selected_action 496.8186572794321 q_best_action 496.46517475492453
# State 3 : q_selected_action 49.681865727943205 q_best_action 49.64651747549245
# State 4 : q_selected_action 49.681865727943205 q_best_action 49.64651747549245
# State 5 : q_selected_action 49.681865727943205 q_best_action 49.64651747549245
# State 6 : q_selected_action 49.681865727943205 q_best_action 49.64651747549245
# State 7 : q_selected_action 49.681865727943205 q_best_action 49.64651747549245
# State 8 : q_selected_action 49.681865727943205 q_best_action 49.64651747549245
# Iterations: 48
# State 0 : q_selected_action 49.71367915514889 q_best_action 49.681865727943205
# State 1 : q_selected_action 49.71367915514889 q_best_action 49.681865727943205
# State 2 : q_selected_action 497.1367915514889 q_best_action 496.8186572794321
# State 3 : q_selected_action 49.71367915514889 q_best_action 49.681865727943205
# State 4 : q_selected_action 49.71367915514889 q_best_action 49.681865727943205
# State 5 : q_selected_action 49.71367915514889 q_best_action 49.681865727943205
# State 6 : q_selected_action 49.71367915514889 q_best_action 49.681865727943205
# State 7 : q_selected_action 49.71367915514889 q_best_action 49.681865727943205
# State 8 : q_selected_action 49.71367915514889 q_best_action 49.681865727943205
# Iterations: 49
# State 0 : q_selected_action 49.742311239634 q_best_action 49.71367915514889
# State 1 : q_selected_action 49.742311239634 q_best_action 49.71367915514889
# State 2 : q_selected_action 497.42311239634 q_best_action 497.1367915514889
# State 3 : q_selected_action 49.742311239634 q_best_action 49.71367915514889
# State 4 : q_selected_action 49.742311239634 q_best_action 49.71367915514889
# State 5 : q_selected_action 49.742311239634 q_best_action 49.71367915514889
# State 6 : q_selected_action 49.742311239634 q_best_action 49.71367915514889
# State 7 : q_selected_action 49.742311239634 q_best_action 49.71367915514889
# State 8 : q_selected_action 49.742311239634 q_best_action 49.71367915514889
# Iterations: 50
# State 0 : q_selected_action 49.7680801156706 q_best_action 49.742311239634
# State 1 : q_selected_action 49.7680801156706 q_best_action 49.742311239634
# State 2 : q_selected_action 497.680801156706 q_best_action 497.42311239634
# State 3 : q_selected_action 49.7680801156706 q_best_action 49.742311239634
# State 4 : q_selected_action 49.7680801156706 q_best_action 49.742311239634
# State 5 : q_selected_action 49.7680801156706 q_best_action 49.742311239634
# State 6 : q_selected_action 49.7680801156706 q_best_action 49.742311239634
# State 7 : q_selected_action 49.7680801156706 q_best_action 49.742311239634
# State 8 : q_selected_action 49.7680801156706 q_best_action 49.742311239634
# Iterations: 51
# State 0 : q_selected_action 49.79127210410354 q_best_action 49.7680801156706
# State 1 : q_selected_action 49.79127210410354 q_best_action 49.7680801156706
# State 2 : q_selected_action 497.9127210410354 q_best_action 497.680801156706
# State 3 : q_selected_action 49.79127210410354 q_best_action 49.7680801156706
# State 4 : q_selected_action 49.79127210410354 q_best_action 49.7680801156706
# State 5 : q_selected_action 49.79127210410354 q_best_action 49.7680801156706
# State 6 : q_selected_action 49.79127210410354 q_best_action 49.7680801156706
# State 7 : q_selected_action 49.79127210410354 q_best_action 49.7680801156706
# State 8 : q_selected_action 49.79127210410354 q_best_action 49.7680801156706
# Iterations: 52
# State 0 : q_selected_action 49.81214489369319 q_best_action 49.79127210410354
# State 1 : q_selected_action 49.81214489369319 q_best_action 49.79127210410354
# State 2 : q_selected_action 498.12144893693187 q_best_action 497.9127210410354
# State 3 : q_selected_action 49.81214489369319 q_best_action 49.79127210410354
# State 4 : q_selected_action 49.81214489369319 q_best_action 49.79127210410354
# State 5 : q_selected_action 49.81214489369319 q_best_action 49.79127210410354
# State 6 : q_selected_action 49.81214489369319 q_best_action 49.79127210410354
# State 7 : q_selected_action 49.81214489369319 q_best_action 49.79127210410354
# State 8 : q_selected_action 49.81214489369319 q_best_action 49.79127210410354
# Iterations: 53
# State 0 : q_selected_action 49.83093040432387 q_best_action 49.81214489369319
# State 1 : q_selected_action 49.83093040432387 q_best_action 49.81214489369319
# State 2 : q_selected_action 498.3093040432387 q_best_action 498.12144893693187
# State 3 : q_selected_action 49.83093040432387 q_best_action 49.81214489369319
# State 4 : q_selected_action 49.83093040432387 q_best_action 49.81214489369319
# State 5 : q_selected_action 49.83093040432387 q_best_action 49.81214489369319
# State 6 : q_selected_action 49.83093040432387 q_best_action 49.81214489369319
# State 7 : q_selected_action 49.83093040432387 q_best_action 49.81214489369319
# State 8 : q_selected_action 49.83093040432387 q_best_action 49.81214489369319
# Iterations: 54
# State 0 : q_selected_action 49.847837363891486 q_best_action 49.83093040432387
# State 1 : q_selected_action 49.847837363891486 q_best_action 49.83093040432387
# State 2 : q_selected_action 498.47837363891483 q_best_action 498.3093040432387
# State 3 : q_selected_action 49.847837363891486 q_best_action 49.83093040432387
# State 4 : q_selected_action 49.847837363891486 q_best_action 49.83093040432387
# State 5 : q_selected_action 49.847837363891486 q_best_action 49.83093040432387
# State 6 : q_selected_action 49.847837363891486 q_best_action 49.83093040432387
# State 7 : q_selected_action 49.847837363891486 q_best_action 49.83093040432387
# State 8 : q_selected_action 49.847837363891486 q_best_action 49.83093040432387
# Iterations: 55
# State 0 : q_selected_action 49.86305362750234 q_best_action 49.847837363891486
# State 1 : q_selected_action 49.86305362750234 q_best_action 49.847837363891486
# State 2 : q_selected_action 498.63053627502336 q_best_action 498.47837363891483
# State 3 : q_selected_action 49.86305362750234 q_best_action 49.847837363891486
# State 4 : q_selected_action 49.86305362750234 q_best_action 49.847837363891486
# State 5 : q_selected_action 49.86305362750234 q_best_action 49.847837363891486
# State 6 : q_selected_action 49.86305362750234 q_best_action 49.847837363891486
# State 7 : q_selected_action 49.86305362750234 q_best_action 49.847837363891486
# State 8 : q_selected_action 49.86305362750234 q_best_action 49.847837363891486
# Iterations: 56
# State 0 : q_selected_action 49.87674826475211 q_best_action 49.86305362750234
# State 1 : q_selected_action 49.87674826475211 q_best_action 49.86305362750234
# State 2 : q_selected_action 498.76748264752104 q_best_action 498.63053627502336
# State 3 : q_selected_action 49.87674826475211 q_best_action 49.86305362750234
# State 4 : q_selected_action 49.87674826475211 q_best_action 49.86305362750234
# State 5 : q_selected_action 49.87674826475211 q_best_action 49.86305362750234
# State 6 : q_selected_action 49.87674826475211 q_best_action 49.86305362750234
# State 7 : q_selected_action 49.87674826475211 q_best_action 49.86305362750234
# State 8 : q_selected_action 49.87674826475211 q_best_action 49.86305362750234
# Iterations: 57
# State 0 : q_selected_action 49.8890734382769 q_best_action 49.87674826475211
# State 1 : q_selected_action 49.8890734382769 q_best_action 49.87674826475211
# State 2 : q_selected_action 498.8907343827689 q_best_action 498.76748264752104
# State 3 : q_selected_action 49.8890734382769 q_best_action 49.87674826475211
# State 4 : q_selected_action 49.8890734382769 q_best_action 49.87674826475211
# State 5 : q_selected_action 49.8890734382769 q_best_action 49.87674826475211
# State 6 : q_selected_action 49.8890734382769 q_best_action 49.87674826475211
# State 7 : q_selected_action 49.8890734382769 q_best_action 49.87674826475211
# State 8 : q_selected_action 49.8890734382769 q_best_action 49.87674826475211
# Iterations: 58
# State 0 : q_selected_action 49.90016609444921 q_best_action 49.8890734382769
# State 1 : q_selected_action 49.90016609444921 q_best_action 49.8890734382769
# State 2 : q_selected_action 499.001660944492 q_best_action 498.8907343827689
# State 3 : q_selected_action 49.90016609444921 q_best_action 49.8890734382769
# State 4 : q_selected_action 49.90016609444921 q_best_action 49.8890734382769
# State 5 : q_selected_action 49.90016609444921 q_best_action 49.8890734382769
# State 6 : q_selected_action 49.90016609444921 q_best_action 49.8890734382769
# State 7 : q_selected_action 49.90016609444921 q_best_action 49.8890734382769
# State 8 : q_selected_action 49.90016609444921 q_best_action 49.8890734382769
# Iterations: 59
# State 0 : q_selected_action 49.91014948500429 q_best_action 49.90016609444921
# State 1 : q_selected_action 49.91014948500429 q_best_action 49.90016609444921
# State 2 : q_selected_action 499.1014948500428 q_best_action 499.001660944492
# State 3 : q_selected_action 49.91014948500429 q_best_action 49.90016609444921
# State 4 : q_selected_action 49.91014948500429 q_best_action 49.90016609444921
# State 5 : q_selected_action 49.91014948500429 q_best_action 49.90016609444921
# State 6 : q_selected_action 49.91014948500429 q_best_action 49.90016609444921
# State 7 : q_selected_action 49.91014948500429 q_best_action 49.90016609444921
# State 8 : q_selected_action 49.91014948500429 q_best_action 49.90016609444921
# Iterations: 60
# State 0 : q_selected_action 49.91913453650386 q_best_action 49.91014948500429
# State 1 : q_selected_action 49.91913453650386 q_best_action 49.91014948500429
# State 2 : q_selected_action 499.1913453650385 q_best_action 499.1014948500428
# State 3 : q_selected_action 49.91913453650386 q_best_action 49.91014948500429
# State 4 : q_selected_action 49.91913453650386 q_best_action 49.91014948500429
# State 5 : q_selected_action 49.91913453650386 q_best_action 49.91014948500429
# State 6 : q_selected_action 49.91913453650386 q_best_action 49.91014948500429
# State 7 : q_selected_action 49.91913453650386 q_best_action 49.91014948500429
# State 8 : q_selected_action 49.91913453650386 q_best_action 49.91014948500429
# Iterations: 61
# State 0 : q_selected_action 49.92722108285348 q_best_action 49.91913453650386
# State 1 : q_selected_action 49.92722108285348 q_best_action 49.91913453650386
# State 2 : q_selected_action 499.27221082853464 q_best_action 499.1913453650385
# State 3 : q_selected_action 49.92722108285348 q_best_action 49.91913453650386
# State 4 : q_selected_action 49.92722108285348 q_best_action 49.91913453650386
# State 5 : q_selected_action 49.92722108285348 q_best_action 49.91913453650386
# State 6 : q_selected_action 49.92722108285348 q_best_action 49.91913453650386
# State 7 : q_selected_action 49.92722108285348 q_best_action 49.91913453650386
# State 8 : q_selected_action 49.92722108285348 q_best_action 49.91913453650386
# Iterations: 62
# State 0 : q_selected_action 49.93449897456813 q_best_action 49.92722108285348
# State 1 : q_selected_action 49.93449897456813 q_best_action 49.92722108285348
# State 2 : q_selected_action 499.3449897456812 q_best_action 499.27221082853464
# State 3 : q_selected_action 49.93449897456813 q_best_action 49.92722108285348
# State 4 : q_selected_action 49.93449897456813 q_best_action 49.92722108285348
# State 5 : q_selected_action 49.93449897456813 q_best_action 49.92722108285348
# State 6 : q_selected_action 49.93449897456813 q_best_action 49.92722108285348
# State 7 : q_selected_action 49.93449897456813 q_best_action 49.92722108285348
# State 8 : q_selected_action 49.93449897456813 q_best_action 49.92722108285348
# Iterations: 63
# State 0 : q_selected_action 49.941049077111316 q_best_action 49.93449897456813
# State 1 : q_selected_action 49.941049077111316 q_best_action 49.93449897456813
# State 2 : q_selected_action 499.4104907711131 q_best_action 499.3449897456812
# State 3 : q_selected_action 49.941049077111316 q_best_action 49.93449897456813
# State 4 : q_selected_action 49.941049077111316 q_best_action 49.93449897456813
# State 5 : q_selected_action 49.941049077111316 q_best_action 49.93449897456813
# State 6 : q_selected_action 49.941049077111316 q_best_action 49.93449897456813
# State 7 : q_selected_action 49.941049077111316 q_best_action 49.93449897456813
# State 8 : q_selected_action 49.941049077111316 q_best_action 49.93449897456813
# Iterations: 64
# State 0 : q_selected_action 49.94694416940018 q_best_action 49.941049077111316
# State 1 : q_selected_action 49.94694416940018 q_best_action 49.941049077111316
# State 2 : q_selected_action 499.4694416940018 q_best_action 499.4104907711131
# State 3 : q_selected_action 49.94694416940018 q_best_action 49.941049077111316
# State 4 : q_selected_action 49.94694416940018 q_best_action 49.941049077111316
# State 5 : q_selected_action 49.94694416940018 q_best_action 49.941049077111316
# State 6 : q_selected_action 49.94694416940018 q_best_action 49.941049077111316
# State 7 : q_selected_action 49.94694416940018 q_best_action 49.941049077111316
# State 8 : q_selected_action 49.94694416940018 q_best_action 49.941049077111316
# Iterations: 65
# State 0 : q_selected_action 49.95224975246017 q_best_action 49.94694416940018
# State 1 : q_selected_action 49.95224975246017 q_best_action 49.94694416940018
# State 2 : q_selected_action 499.5224975246016 q_best_action 499.4694416940018
# State 3 : q_selected_action 49.95224975246017 q_best_action 49.94694416940018
# State 4 : q_selected_action 49.95224975246017 q_best_action 49.94694416940018
# State 5 : q_selected_action 49.95224975246017 q_best_action 49.94694416940018
# State 6 : q_selected_action 49.95224975246017 q_best_action 49.94694416940018
# State 7 : q_selected_action 49.95224975246017 q_best_action 49.94694416940018
# State 8 : q_selected_action 49.95224975246017 q_best_action 49.94694416940018
# Iterations: 66
# State 0 : q_selected_action 49.95702477721415 q_best_action 49.95224975246017
# State 1 : q_selected_action 49.95702477721415 q_best_action 49.95224975246017
# State 2 : q_selected_action 499.57024777214144 q_best_action 499.5224975246016
# State 3 : q_selected_action 49.95702477721415 q_best_action 49.95224975246017
# State 4 : q_selected_action 49.95702477721415 q_best_action 49.95224975246017
# State 5 : q_selected_action 49.95702477721415 q_best_action 49.95224975246017
# State 6 : q_selected_action 49.95702477721415 q_best_action 49.95224975246017
# State 7 : q_selected_action 49.95702477721415 q_best_action 49.95224975246017
# State 8 : q_selected_action 49.95702477721415 q_best_action 49.95224975246017
# Iterations: 67
# State 0 : q_selected_action 49.961322299492736 q_best_action 49.95702477721415
# State 1 : q_selected_action 49.961322299492736 q_best_action 49.95702477721415
# State 2 : q_selected_action 499.6132229949273 q_best_action 499.57024777214144
# State 3 : q_selected_action 49.961322299492736 q_best_action 49.95702477721415
# State 4 : q_selected_action 49.961322299492736 q_best_action 49.95702477721415
# State 5 : q_selected_action 49.961322299492736 q_best_action 49.95702477721415
# State 6 : q_selected_action 49.961322299492736 q_best_action 49.95702477721415
# State 7 : q_selected_action 49.961322299492736 q_best_action 49.95702477721415
# State 8 : q_selected_action 49.961322299492736 q_best_action 49.95702477721415
# Iterations: 68
# State 0 : q_selected_action 49.96519006954346 q_best_action 49.961322299492736
# State 1 : q_selected_action 49.96519006954346 q_best_action 49.961322299492736
# State 2 : q_selected_action 499.65190069543456 q_best_action 499.6132229949273
# State 3 : q_selected_action 49.96519006954346 q_best_action 49.961322299492736
# State 4 : q_selected_action 49.96519006954346 q_best_action 49.961322299492736
# State 5 : q_selected_action 49.96519006954346 q_best_action 49.961322299492736
# State 6 : q_selected_action 49.96519006954346 q_best_action 49.961322299492736
# State 7 : q_selected_action 49.96519006954346 q_best_action 49.961322299492736
# State 8 : q_selected_action 49.96519006954346 q_best_action 49.961322299492736
# Iterations: 69
# State 0 : q_selected_action 49.96867106258912 q_best_action 49.96519006954346
# State 1 : q_selected_action 49.96867106258912 q_best_action 49.96519006954346
# State 2 : q_selected_action 499.6867106258911 q_best_action 499.65190069543456
# State 3 : q_selected_action 49.96867106258912 q_best_action 49.96519006954346
# ...
# State 4 : q_selected_action 49.99999999999966 q_best_action 49.999999999999616
# State 5 : q_selected_action 49.99999999999966 q_best_action 49.999999999999616
# State 6 : q_selected_action 49.99999999999966 q_best_action 49.999999999999616
# State 7 : q_selected_action 49.99999999999966 q_best_action 49.999999999999616
# State 8 : q_selected_action 49.99999999999966 q_best_action 49.999999999999616
# Iterations: 309
# State 0 : q_selected_action 49.999999999999694 q_best_action 49.99999999999966
# State 1 : q_selected_action 49.999999999999694 q_best_action 49.99999999999966
# State 2 : q_selected_action 499.9999999999968 q_best_action 499.9999999999965
# State 3 : q_selected_action 49.999999999999694 q_best_action 49.99999999999966
# State 4 : q_selected_action 49.999999999999694 q_best_action 49.99999999999966
# State 5 : q_selected_action 49.999999999999694 q_best_action 49.99999999999966
# State 6 : q_selected_action 49.999999999999694 q_best_action 49.99999999999966
# State 7 : q_selected_action 49.999999999999694 q_best_action 49.99999999999966
# State 8 : q_selected_action 49.999999999999694 q_best_action 49.99999999999966
# Iterations: 310
# State 0 : q_selected_action 49.99999999999972 q_best_action 49.999999999999694
# State 1 : q_selected_action 49.99999999999972 q_best_action 49.999999999999694
# State 2 : q_selected_action 499.99999999999716 q_best_action 499.9999999999968
# State 3 : q_selected_action 49.99999999999972 q_best_action 49.999999999999694
# State 4 : q_selected_action 49.99999999999972 q_best_action 49.999999999999694
# State 5 : q_selected_action 49.99999999999972 q_best_action 49.999999999999694
# State 6 : q_selected_action 49.99999999999972 q_best_action 49.999999999999694
# State 7 : q_selected_action 49.99999999999972 q_best_action 49.999999999999694
# State 8 : q_selected_action 49.99999999999972 q_best_action 49.999999999999694
# Iterations: 311
# State 0 : q_selected_action 49.99999999999975 q_best_action 49.99999999999972
# State 1 : q_selected_action 49.99999999999975 q_best_action 49.99999999999972
# State 2 : q_selected_action 499.99999999999744 q_best_action 499.99999999999716
# State 3 : q_selected_action 49.99999999999975 q_best_action 49.99999999999972
# State 4 : q_selected_action 49.99999999999975 q_best_action 49.99999999999972
# State 5 : q_selected_action 49.99999999999975 q_best_action 49.99999999999972
# State 6 : q_selected_action 49.99999999999975 q_best_action 49.99999999999972
# State 7 : q_selected_action 49.99999999999975 q_best_action 49.99999999999972
# State 8 : q_selected_action 49.99999999999975 q_best_action 49.99999999999972
# Iterations: 312
# State 0 : q_selected_action 49.99999999999978 q_best_action 49.99999999999975
# State 1 : q_selected_action 49.99999999999978 q_best_action 49.99999999999975
# State 2 : q_selected_action 499.9999999999977 q_best_action 499.99999999999744
# State 3 : q_selected_action 49.99999999999978 q_best_action 49.99999999999975
# State 4 : q_selected_action 49.99999999999978 q_best_action 49.99999999999975
# State 5 : q_selected_action 49.99999999999978 q_best_action 49.99999999999975
# State 6 : q_selected_action 49.99999999999978 q_best_action 49.99999999999975
# State 7 : q_selected_action 49.99999999999978 q_best_action 49.99999999999975
# State 8 : q_selected_action 49.99999999999978 q_best_action 49.99999999999975
# Iterations: 313
# State 0 : q_selected_action 49.9999999999998 q_best_action 49.99999999999978
# State 1 : q_selected_action 49.9999999999998 q_best_action 49.99999999999978
# State 2 : q_selected_action 499.99999999999795 q_best_action 499.9999999999977
# State 3 : q_selected_action 49.9999999999998 q_best_action 49.99999999999978
# State 4 : q_selected_action 49.9999999999998 q_best_action 49.99999999999978
# State 5 : q_selected_action 49.9999999999998 q_best_action 49.99999999999978
# State 6 : q_selected_action 49.9999999999998 q_best_action 49.99999999999978
# State 7 : q_selected_action 49.9999999999998 q_best_action 49.99999999999978
# State 8 : q_selected_action 49.9999999999998 q_best_action 49.99999999999978
# Iterations: 314
# State 0 : q_selected_action 49.99999999999982 q_best_action 49.9999999999998
# State 1 : q_selected_action 49.99999999999982 q_best_action 49.9999999999998
# State 2 : q_selected_action 499.9999999999982 q_best_action 499.99999999999795
# State 3 : q_selected_action 49.99999999999982 q_best_action 49.9999999999998
# State 4 : q_selected_action 49.99999999999982 q_best_action 49.9999999999998
# State 5 : q_selected_action 49.99999999999982 q_best_action 49.9999999999998
# State 6 : q_selected_action 49.99999999999982 q_best_action 49.9999999999998
# State 7 : q_selected_action 49.99999999999982 q_best_action 49.9999999999998
# State 8 : q_selected_action 49.99999999999982 q_best_action 49.9999999999998
# Iterations: 315
# State 0 : q_selected_action 49.999999999999844 q_best_action 49.99999999999982
# State 1 : q_selected_action 49.999999999999844 q_best_action 49.99999999999982
# State 2 : q_selected_action 499.99999999999835 q_best_action 499.9999999999982
# State 3 : q_selected_action 49.999999999999844 q_best_action 49.99999999999982
# State 4 : q_selected_action 49.999999999999844 q_best_action 49.99999999999982
# State 5 : q_selected_action 49.999999999999844 q_best_action 49.99999999999982
# State 6 : q_selected_action 49.999999999999844 q_best_action 49.99999999999982
# State 7 : q_selected_action 49.999999999999844 q_best_action 49.99999999999982
# State 8 : q_selected_action 49.999999999999844 q_best_action 49.99999999999982
# Iterations: 316
# State 0 : q_selected_action 49.99999999999986 q_best_action 49.999999999999844
# State 1 : q_selected_action 49.99999999999986 q_best_action 49.999999999999844
# State 2 : q_selected_action 499.9999999999985 q_best_action 499.99999999999835
# State 3 : q_selected_action 49.99999999999986 q_best_action 49.999999999999844
# State 4 : q_selected_action 49.99999999999986 q_best_action 49.999999999999844
# State 5 : q_selected_action 49.99999999999986 q_best_action 49.999999999999844
# State 6 : q_selected_action 49.99999999999986 q_best_action 49.999999999999844
# State 7 : q_selected_action 49.99999999999986 q_best_action 49.999999999999844
# State 8 : q_selected_action 49.99999999999986 q_best_action 49.999999999999844
# Iterations: 317
# State 0 : q_selected_action 49.99999999999987 q_best_action 49.99999999999986
# State 1 : q_selected_action 49.99999999999987 q_best_action 49.99999999999986
# State 2 : q_selected_action 499.9999999999987 q_best_action 499.9999999999985
# State 3 : q_selected_action 49.99999999999987 q_best_action 49.99999999999986
# State 4 : q_selected_action 49.99999999999987 q_best_action 49.99999999999986
# State 5 : q_selected_action 49.99999999999987 q_best_action 49.99999999999986
# State 6 : q_selected_action 49.99999999999987 q_best_action 49.99999999999986
# State 7 : q_selected_action 49.99999999999987 q_best_action 49.99999999999986
# State 8 : q_selected_action 49.99999999999987 q_best_action 49.99999999999986
# Iterations: 318
# State 0 : q_selected_action 49.999999999999886 q_best_action 49.99999999999987
# State 1 : q_selected_action 49.999999999999886 q_best_action 49.99999999999987
# State 2 : q_selected_action 499.9999999999988 q_best_action 499.9999999999987
# State 3 : q_selected_action 49.999999999999886 q_best_action 49.99999999999987
# State 4 : q_selected_action 49.999999999999886 q_best_action 49.99999999999987
# State 5 : q_selected_action 49.999999999999886 q_best_action 49.99999999999987
# State 6 : q_selected_action 49.999999999999886 q_best_action 49.99999999999987
# State 7 : q_selected_action 49.999999999999886 q_best_action 49.99999999999987
# State 8 : q_selected_action 49.999999999999886 q_best_action 49.99999999999987
# Iterations: 319
# State 0 : q_selected_action 49.9999999999999 q_best_action 49.999999999999886
# State 1 : q_selected_action 49.9999999999999 q_best_action 49.999999999999886
# State 2 : q_selected_action 499.9999999999989 q_best_action 499.9999999999988
# State 3 : q_selected_action 49.9999999999999 q_best_action 49.999999999999886
# State 4 : q_selected_action 49.9999999999999 q_best_action 49.999999999999886
# State 5 : q_selected_action 49.9999999999999 q_best_action 49.999999999999886
# State 6 : q_selected_action 49.9999999999999 q_best_action 49.999999999999886
# State 7 : q_selected_action 49.9999999999999 q_best_action 49.999999999999886
# State 8 : q_selected_action 49.9999999999999 q_best_action 49.999999999999886
# Iterations: 320
# State 0 : q_selected_action 49.999999999999915 q_best_action 49.9999999999999
# State 1 : q_selected_action 49.999999999999915 q_best_action 49.9999999999999
# State 2 : q_selected_action 499.99999999999903 q_best_action 499.9999999999989
# State 3 : q_selected_action 49.999999999999915 q_best_action 49.9999999999999
# State 4 : q_selected_action 49.999999999999915 q_best_action 49.9999999999999
# State 5 : q_selected_action 49.999999999999915 q_best_action 49.9999999999999
# State 6 : q_selected_action 49.999999999999915 q_best_action 49.9999999999999
# State 7 : q_selected_action 49.999999999999915 q_best_action 49.9999999999999
# State 8 : q_selected_action 49.999999999999915 q_best_action 49.9999999999999
# Iterations: 321
# State 0 : q_selected_action 49.99999999999992 q_best_action 49.999999999999915
# State 1 : q_selected_action 49.99999999999992 q_best_action 49.999999999999915
# State 2 : q_selected_action 499.99999999999915 q_best_action 499.99999999999903
# State 3 : q_selected_action 49.99999999999992 q_best_action 49.999999999999915
# State 4 : q_selected_action 49.99999999999992 q_best_action 49.999999999999915
# State 5 : q_selected_action 49.99999999999992 q_best_action 49.999999999999915
# State 6 : q_selected_action 49.99999999999992 q_best_action 49.999999999999915
# State 7 : q_selected_action 49.99999999999992 q_best_action 49.999999999999915
# State 8 : q_selected_action 49.99999999999992 q_best_action 49.999999999999915
# Iterations: 322
# State 0 : q_selected_action 49.99999999999993 q_best_action 49.99999999999992
# State 1 : q_selected_action 49.99999999999993 q_best_action 49.99999999999992
# State 2 : q_selected_action 499.99999999999926 q_best_action 499.99999999999915
# State 3 : q_selected_action 49.99999999999993 q_best_action 49.99999999999992
# State 4 : q_selected_action 49.99999999999993 q_best_action 49.99999999999992
# State 5 : q_selected_action 49.99999999999993 q_best_action 49.99999999999992
# State 6 : q_selected_action 49.99999999999993 q_best_action 49.99999999999992
# State 7 : q_selected_action 49.99999999999993 q_best_action 49.99999999999992
# State 8 : q_selected_action 49.99999999999993 q_best_action 49.99999999999992
# Iterations: 323
# State 0 : q_selected_action 49.999999999999936 q_best_action 49.99999999999993
# State 1 : q_selected_action 49.999999999999936 q_best_action 49.99999999999993
# State 2 : q_selected_action 499.9999999999993 q_best_action 499.99999999999926
# State 3 : q_selected_action 49.999999999999936 q_best_action 49.99999999999993
# State 4 : q_selected_action 49.999999999999936 q_best_action 49.99999999999993
# State 5 : q_selected_action 49.999999999999936 q_best_action 49.99999999999993
# State 6 : q_selected_action 49.999999999999936 q_best_action 49.99999999999993
# State 7 : q_selected_action 49.999999999999936 q_best_action 49.99999999999993
# State 8 : q_selected_action 49.999999999999936 q_best_action 49.99999999999993
# Iterations: 324
# State 0 : q_selected_action 49.99999999999994 q_best_action 49.999999999999936
# State 1 : q_selected_action 49.99999999999994 q_best_action 49.999999999999936
# State 2 : q_selected_action 499.9999999999994 q_best_action 499.9999999999993
# State 3 : q_selected_action 49.99999999999994 q_best_action 49.999999999999936
# State 4 : q_selected_action 49.99999999999994 q_best_action 49.999999999999936
# State 5 : q_selected_action 49.99999999999994 q_best_action 49.999999999999936
# State 6 : q_selected_action 49.99999999999994 q_best_action 49.999999999999936
# State 7 : q_selected_action 49.99999999999994 q_best_action 49.999999999999936
# State 8 : q_selected_action 49.99999999999994 q_best_action 49.999999999999936
# Iterations: 325
# State 0 : q_selected_action 49.99999999999995 q_best_action 49.99999999999994
# State 1 : q_selected_action 49.99999999999995 q_best_action 49.99999999999994
# State 2 : q_selected_action 499.99999999999943 q_best_action 499.9999999999994
# State 3 : q_selected_action 49.99999999999995 q_best_action 49.99999999999994
# State 4 : q_selected_action 49.99999999999995 q_best_action 49.99999999999994
# State 5 : q_selected_action 49.99999999999995 q_best_action 49.99999999999994
# State 6 : q_selected_action 49.99999999999995 q_best_action 49.99999999999994
# State 7 : q_selected_action 49.99999999999995 q_best_action 49.99999999999994
# State 8 : q_selected_action 49.99999999999995 q_best_action 49.99999999999994
# Iterations: 326
# State 0 : q_selected_action 49.99999999999996 q_best_action 49.99999999999995
# State 1 : q_selected_action 49.99999999999996 q_best_action 49.99999999999995
# State 2 : q_selected_action 499.9999999999995 q_best_action 499.99999999999943
# State 3 : q_selected_action 49.99999999999996 q_best_action 49.99999999999995
# State 4 : q_selected_action 49.99999999999996 q_best_action 49.99999999999995
# State 5 : q_selected_action 49.99999999999996 q_best_action 49.99999999999995
# State 6 : q_selected_action 49.99999999999996 q_best_action 49.99999999999995
# State 7 : q_selected_action 49.99999999999996 q_best_action 49.99999999999995
# State 8 : q_selected_action 49.99999999999996 q_best_action 49.99999999999995
# Iterations: 327
# State 0 : q_selected_action 49.999999999999964 q_best_action 49.99999999999996
# State 1 : q_selected_action 49.999999999999964 q_best_action 49.99999999999996
# State 2 : q_selected_action 499.99999999999955 q_best_action 499.9999999999995
# State 3 : q_selected_action 49.999999999999964 q_best_action 49.99999999999996
# State 4 : q_selected_action 49.999999999999964 q_best_action 49.99999999999996
# State 5 : q_selected_action 49.999999999999964 q_best_action 49.99999999999996
# State 6 : q_selected_action 49.999999999999964 q_best_action 49.99999999999996
# State 7 : q_selected_action 49.999999999999964 q_best_action 49.99999999999996
# State 8 : q_selected_action 49.999999999999964 q_best_action 49.99999999999996
# Iterations: 328
# State 0 : q_selected_action 49.99999999999997 q_best_action 49.999999999999964
# State 1 : q_selected_action 49.99999999999997 q_best_action 49.999999999999964
# State 2 : q_selected_action 499.9999999999996 q_best_action 499.99999999999955
# State 3 : q_selected_action 49.99999999999997 q_best_action 49.999999999999964
# State 4 : q_selected_action 49.99999999999997 q_best_action 49.999999999999964
# State 5 : q_selected_action 49.99999999999997 q_best_action 49.999999999999964
# State 6 : q_selected_action 49.99999999999997 q_best_action 49.999999999999964
# State 7 : q_selected_action 49.99999999999997 q_best_action 49.999999999999964
# State 8 : q_selected_action 49.99999999999997 q_best_action 49.999999999999964
# Iterations: 329
# State 0 : q_selected_action 49.99999999999998 q_best_action 49.99999999999997
# State 1 : q_selected_action 49.99999999999998 q_best_action 49.99999999999997
# State 2 : q_selected_action 499.99999999999966 q_best_action 499.9999999999996
# State 3 : q_selected_action 49.99999999999998 q_best_action 49.99999999999997
# State 4 : q_selected_action 49.99999999999998 q_best_action 49.99999999999997
# State 5 : q_selected_action 49.99999999999998 q_best_action 49.99999999999997
# State 6 : q_selected_action 49.99999999999998 q_best_action 49.99999999999997
# State 7 : q_selected_action 49.99999999999998 q_best_action 49.99999999999997
# State 8 : q_selected_action 49.99999999999998 q_best_action 49.99999999999997
# Iterations: 330
# State 2 : q_selected_action 499.9999999999997 q_best_action 499.99999999999966
# Iterations: 331
# State 2 : q_selected_action 499.9999999999998 q_best_action 499.9999999999997
# Iterations: 332
# State 2 : q_selected_action 499.99999999999983 q_best_action 499.9999999999998
# Iterations: 333
# Iterations: 334
# Optimal policy
# [4, 4, 5, 4, 4, 4, 4, 4, 4]
# [ 50.  50. 500.  50.  50.  50.  50.  50.  50.]

# %%
# !cp drive/MyDrive/Colab_Notebooks/DP_Office_env.ipynb ./

# %%
# !apt-get update
# !apt-get install texlive texlive-xetex texlive-latex-extra pandoc --fix-missing
# !pip install pypandoc
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:10 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,045 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:12 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,402 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:14 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:15 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [52.7 kB]
# Hit:16 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:19 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,749 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,476 kB]
# Get:21 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [895 kB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,172 kB]
# Get:23 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [39.5 kB]
# Fetched 11.1 MB in 3s (3,805 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# pandoc is already the newest version (1.19.2.4~dfsg-1build4).
# pandoc set to manually installed.
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-lato fonts-lmodern fonts-noto-mono fonts-texgyre
#   javascript-common libcupsfilters1 libcupsimage2 libgs9 libgs9-common
#   libijs-0.35 libjbig2dec0 libjs-jquery libkpathsea6 libpotrace0 libptexenc1
#   libruby2.5 libsynctex1 libtexlua52 libtexluajit2 libzzip-0-13 lmodern
#   poppler-data preview-latex-style rake ruby ruby-did-you-mean ruby-minitest
#   ruby-net-telnet ruby-power-assert ruby-test-unit ruby2.5
#   rubygems-integration t1utils tex-common tex-gyre texlive-base
#   texlive-binaries texlive-fonts-recommended texlive-latex-base
#   texlive-latex-recommended texlive-pictures texlive-plain-generic tipa
# Suggested packages:
#   fonts-noto apache2 | lighttpd | httpd poppler-utils ghostscript
#   fonts-japanese-mincho | fonts-ipafont-mincho fonts-japanese-gothic
#   | fonts-ipafont-gothic fonts-arphic-ukai fonts-arphic-uming fonts-nanum ri
#   ruby-dev bundler debhelper gv | postscript-viewer perl-tk xpdf-reader
#   | pdf-viewer texlive-fonts-recommended-doc texlive-latex-base-doc
#   python-pygments icc-profiles libfile-which-perl
#   libspreadsheet-parseexcel-perl texlive-latex-extra-doc
#   texlive-latex-recommended-doc texlive-pstricks dot2tex prerex ruby-tcltk
#   | libtcltk-ruby texlive-pictures-doc vprerex
# The following NEW packages will be installed:
#   fonts-droid-fallback fonts-lato fonts-lmodern fonts-noto-mono fonts-texgyre
#   javascript-common libcupsfilters1 libcupsimage2 libgs9 libgs9-common
#   libijs-0.35 libjbig2dec0 libjs-jquery libkpathsea6 libpotrace0 libptexenc1
#   libruby2.5 libsynctex1 libtexlua52 libtexluajit2 libzzip-0-13 lmodern
#   poppler-data preview-latex-style rake ruby ruby-did-you-mean ruby-minitest
#   ruby-net-telnet ruby-power-assert ruby-test-unit ruby2.5
#   rubygems-integration t1utils tex-common tex-gyre texlive texlive-base
#   texlive-binaries texlive-fonts-recommended texlive-latex-base
#   texlive-latex-extra texlive-latex-recommended texlive-pictures
#   texlive-plain-generic texlive-xetex tipa
# 0 upgraded, 47 newly installed, 0 to remove and 51 not upgraded.
# Need to get 146 MB of archives.
# After this operation, 460 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-lato all 2.0-2 [2,698 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 poppler-data all 0.4.8-2 [1,479 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/main amd64 tex-common all 6.09 [33.0 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-lmodern all 2.004.5-3 [4,551 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 fonts-noto-mono all 20171026-2 [75.5 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-texgyre all 20160520-1 [8,761 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 javascript-common all 11 [6,066 B]
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcupsfilters1 amd64 1.20.2-0ubuntu3.1 [108 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcupsimage2 amd64 2.2.7-1ubuntu2.8 [18.6 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libijs-0.35 amd64 0.35-13 [15.5 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjbig2dec0 amd64 0.13-6 [55.9 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgs9-common all 9.26~dfsg+0-0ubuntu0.18.04.14 [5,092 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libgs9 amd64 9.26~dfsg+0-0ubuntu0.18.04.14 [2,265 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libjs-jquery all 3.2.1-1 [152 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libkpathsea6 amd64 2017.20170613.44572-8ubuntu0.1 [54.9 kB]
# Get:17 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpotrace0 amd64 1.14-2 [17.4 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libptexenc1 amd64 2017.20170613.44572-8ubuntu0.1 [34.5 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 rubygems-integration all 1.11 [4,994 B]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ruby2.5 amd64 2.5.1-1ubuntu1.8 [48.6 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/main amd64 ruby amd64 1:2.5.1 [5,712 B]
# Get:22 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 rake all 12.3.1-1ubuntu0.1 [44.9 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 ruby-did-you-mean all 1.2.0-2 [9,700 B]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 ruby-minitest all 5.10.3-1 [38.6 kB]
# Get:25 http://archive.ubuntu.com/ubuntu bionic/main amd64 ruby-net-telnet all 0.1.1-2 [12.6 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic/main amd64 ruby-power-assert all 0.3.0-1 [7,952 B]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 ruby-test-unit all 3.2.5-1 [61.1 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libruby2.5 amd64 2.5.1-1ubuntu1.8 [3,069 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libsynctex1 amd64 2017.20170613.44572-8ubuntu0.1 [41.4 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libtexlua52 amd64 2017.20170613.44572-8ubuntu0.1 [91.2 kB]
# Get:31 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libtexluajit2 amd64 2017.20170613.44572-8ubuntu0.1 [230 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libzzip-0-13 amd64 0.13.62-3.1ubuntu0.18.04.1 [26.0 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic/main amd64 lmodern all 2.004.5-3 [9,631 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/main amd64 preview-latex-style all 11.91-1ubuntu1 [185 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic/main amd64 t1utils amd64 1.41-2 [56.0 kB]
# Get:36 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tex-gyre all 20160520-1 [4,998 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 texlive-binaries amd64 2017.20170613.44572-8ubuntu0.1 [8,179 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic/main amd64 texlive-base all 2017.20180305-1 [18.7 MB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic/universe amd64 texlive-fonts-recommended all 2017.20180305-1 [5,262 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/main amd64 texlive-latex-base all 2017.20180305-1 [951 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/main amd64 texlive-latex-recommended all 2017.20180305-1 [14.9 MB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/universe amd64 texlive all 2017.20180305-1 [14.4 kB]
# Get:43 http://archive.ubuntu.com/ubuntu bionic/universe amd64 texlive-pictures all 2017.20180305-1 [4,026 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic/universe amd64 texlive-latex-extra all 2017.20180305-2 [10.6 MB]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/universe amd64 texlive-plain-generic all 2017.20180305-2 [23.6 MB]
# Get:46 http://archive.ubuntu.com/ubuntu bionic/universe amd64 tipa all 2:1.3-20 [2,978 kB]
# Get:47 http://archive.ubuntu.com/ubuntu bionic/universe amd64 texlive-xetex all 2017.20180305-1 [10.7 MB]
# Fetched 146 MB in 5s (30.8 MB/s)
# Extracting templates from packages: 100%
# Preconfiguring packages ...
# Selecting previously unselected package fonts-droid-fallback.
# (Reading database ... 160980 files and directories currently installed.)
# Preparing to unpack .../00-fonts-droid-fallback_1%3a6.0.1r16-1.1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Selecting previously unselected package fonts-lato.
# Preparing to unpack .../01-fonts-lato_2.0-2_all.deb ...
# Unpacking fonts-lato (2.0-2) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../02-poppler-data_0.4.8-2_all.deb ...
# Unpacking poppler-data (0.4.8-2) ...
# Selecting previously unselected package tex-common.
# Preparing to unpack .../03-tex-common_6.09_all.deb ...
# Unpacking tex-common (6.09) ...
# Selecting previously unselected package fonts-lmodern.
# Preparing to unpack .../04-fonts-lmodern_2.004.5-3_all.deb ...
# Unpacking fonts-lmodern (2.004.5-3) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../05-fonts-noto-mono_20171026-2_all.deb ...
# Unpacking fonts-noto-mono (20171026-2) ...
# Selecting previously unselected package fonts-texgyre.
# Preparing to unpack .../06-fonts-texgyre_20160520-1_all.deb ...
# Unpacking fonts-texgyre (20160520-1) ...
# Selecting previously unselected package javascript-common.
# Preparing to unpack .../07-javascript-common_11_all.deb ...
# Unpacking javascript-common (11) ...
# Selecting previously unselected package libcupsfilters1:amd64.
# Preparing to unpack .../08-libcupsfilters1_1.20.2-0ubuntu3.1_amd64.deb ...
# Unpacking libcupsfilters1:amd64 (1.20.2-0ubuntu3.1) ...
# Selecting previously unselected package libcupsimage2:amd64.
# Preparing to unpack .../09-libcupsimage2_2.2.7-1ubuntu2.8_amd64.deb ...
# Unpacking libcupsimage2:amd64 (2.2.7-1ubuntu2.8) ...
# Selecting previously unselected package libijs-0.35:amd64.
# Preparing to unpack .../10-libijs-0.35_0.35-13_amd64.deb ...
# Unpacking libijs-0.35:amd64 (0.35-13) ...
# Selecting previously unselected package libjbig2dec0:amd64.
# Preparing to unpack .../11-libjbig2dec0_0.13-6_amd64.deb ...
# Unpacking libjbig2dec0:amd64 (0.13-6) ...
# Selecting previously unselected package libgs9-common.
# Preparing to unpack .../12-libgs9-common_9.26~dfsg+0-0ubuntu0.18.04.14_all.deb ...
# Unpacking libgs9-common (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Selecting previously unselected package libgs9:amd64.
# Preparing to unpack .../13-libgs9_9.26~dfsg+0-0ubuntu0.18.04.14_amd64.deb ...
# Unpacking libgs9:amd64 (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Selecting previously unselected package libjs-jquery.
# Preparing to unpack .../14-libjs-jquery_3.2.1-1_all.deb ...
# Unpacking libjs-jquery (3.2.1-1) ...
# Selecting previously unselected package libkpathsea6:amd64.
# Preparing to unpack .../15-libkpathsea6_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libkpathsea6:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libpotrace0.
# Preparing to unpack .../16-libpotrace0_1.14-2_amd64.deb ...
# Unpacking libpotrace0 (1.14-2) ...
# Selecting previously unselected package libptexenc1:amd64.
# Preparing to unpack .../17-libptexenc1_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libptexenc1:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package rubygems-integration.
# Preparing to unpack .../18-rubygems-integration_1.11_all.deb ...
# Unpacking rubygems-integration (1.11) ...
# Selecting previously unselected package ruby2.5.
# Preparing to unpack .../19-ruby2.5_2.5.1-1ubuntu1.8_amd64.deb ...
# Unpacking ruby2.5 (2.5.1-1ubuntu1.8) ...
# Selecting previously unselected package ruby.
# Preparing to unpack .../20-ruby_1%3a2.5.1_amd64.deb ...
# Unpacking ruby (1:2.5.1) ...
# Selecting previously unselected package rake.
# Preparing to unpack .../21-rake_12.3.1-1ubuntu0.1_all.deb ...
# Unpacking rake (12.3.1-1ubuntu0.1) ...
# Selecting previously unselected package ruby-did-you-mean.
# Preparing to unpack .../22-ruby-did-you-mean_1.2.0-2_all.deb ...
# Unpacking ruby-did-you-mean (1.2.0-2) ...
# Selecting previously unselected package ruby-minitest.
# Preparing to unpack .../23-ruby-minitest_5.10.3-1_all.deb ...
# Unpacking ruby-minitest (5.10.3-1) ...
# Selecting previously unselected package ruby-net-telnet.
# Preparing to unpack .../24-ruby-net-telnet_0.1.1-2_all.deb ...
# Unpacking ruby-net-telnet (0.1.1-2) ...
# Selecting previously unselected package ruby-power-assert.
# Preparing to unpack .../25-ruby-power-assert_0.3.0-1_all.deb ...
# Unpacking ruby-power-assert (0.3.0-1) ...
# Selecting previously unselected package ruby-test-unit.
# Preparing to unpack .../26-ruby-test-unit_3.2.5-1_all.deb ...
# Unpacking ruby-test-unit (3.2.5-1) ...
# Selecting previously unselected package libruby2.5:amd64.
# Preparing to unpack .../27-libruby2.5_2.5.1-1ubuntu1.8_amd64.deb ...
# Unpacking libruby2.5:amd64 (2.5.1-1ubuntu1.8) ...
# Selecting previously unselected package libsynctex1:amd64.
# Preparing to unpack .../28-libsynctex1_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libsynctex1:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libtexlua52:amd64.
# Preparing to unpack .../29-libtexlua52_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libtexlua52:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libtexluajit2:amd64.
# Preparing to unpack .../30-libtexluajit2_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking libtexluajit2:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package libzzip-0-13:amd64.
# Preparing to unpack .../31-libzzip-0-13_0.13.62-3.1ubuntu0.18.04.1_amd64.deb ...
# Unpacking libzzip-0-13:amd64 (0.13.62-3.1ubuntu0.18.04.1) ...
# Selecting previously unselected package lmodern.
# Preparing to unpack .../32-lmodern_2.004.5-3_all.deb ...
# Unpacking lmodern (2.004.5-3) ...
# Selecting previously unselected package preview-latex-style.
# Preparing to unpack .../33-preview-latex-style_11.91-1ubuntu1_all.deb ...
# Unpacking preview-latex-style (11.91-1ubuntu1) ...
# Selecting previously unselected package t1utils.
# Preparing to unpack .../34-t1utils_1.41-2_amd64.deb ...
# Unpacking t1utils (1.41-2) ...
# Selecting previously unselected package tex-gyre.
# Preparing to unpack .../35-tex-gyre_20160520-1_all.deb ...
# Unpacking tex-gyre (20160520-1) ...
# Selecting previously unselected package texlive-binaries.
# Preparing to unpack .../36-texlive-binaries_2017.20170613.44572-8ubuntu0.1_amd64.deb ...
# Unpacking texlive-binaries (2017.20170613.44572-8ubuntu0.1) ...
# Selecting previously unselected package texlive-base.
# Preparing to unpack .../37-texlive-base_2017.20180305-1_all.deb ...
# Unpacking texlive-base (2017.20180305-1) ...
# Selecting previously unselected package texlive-fonts-recommended.
# Preparing to unpack .../38-texlive-fonts-recommended_2017.20180305-1_all.deb ...
# Unpacking texlive-fonts-recommended (2017.20180305-1) ...
# Selecting previously unselected package texlive-latex-base.
# Preparing to unpack .../39-texlive-latex-base_2017.20180305-1_all.deb ...
# Unpacking texlive-latex-base (2017.20180305-1) ...
# Selecting previously unselected package texlive-latex-recommended.
# Preparing to unpack .../40-texlive-latex-recommended_2017.20180305-1_all.deb ...
# Unpacking texlive-latex-recommended (2017.20180305-1) ...
# Selecting previously unselected package texlive.
# Preparing to unpack .../41-texlive_2017.20180305-1_all.deb ...
# Unpacking texlive (2017.20180305-1) ...
# Selecting previously unselected package texlive-pictures.
# Preparing to unpack .../42-texlive-pictures_2017.20180305-1_all.deb ...
# Unpacking texlive-pictures (2017.20180305-1) ...
# Selecting previously unselected package texlive-latex-extra.
# Preparing to unpack .../43-texlive-latex-extra_2017.20180305-2_all.deb ...
# Unpacking texlive-latex-extra (2017.20180305-2) ...
# Selecting previously unselected package texlive-plain-generic.
# Preparing to unpack .../44-texlive-plain-generic_2017.20180305-2_all.deb ...
# Unpacking texlive-plain-generic (2017.20180305-2) ...
# Selecting previously unselected package tipa.
# Preparing to unpack .../45-tipa_2%3a1.3-20_all.deb ...
# Unpacking tipa (2:1.3-20) ...
# Selecting previously unselected package texlive-xetex.
# Preparing to unpack .../46-texlive-xetex_2017.20180305-1_all.deb ...
# Unpacking texlive-xetex (2017.20180305-1) ...
# Setting up libgs9-common (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Setting up libkpathsea6:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Setting up libjs-jquery (3.2.1-1) ...
# Setting up libtexlua52:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Setting up fonts-droid-fallback (1:6.0.1r16-1.1) ...
# Setting up libsynctex1:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Setting up libptexenc1:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Setting up tex-common (6.09) ...
# update-language: texlive-base not installed and configured, doing nothing!
# Setting up poppler-data (0.4.8-2) ...
# Setting up tex-gyre (20160520-1) ...
# Setting up preview-latex-style (11.91-1ubuntu1) ...
# Setting up fonts-texgyre (20160520-1) ...
# Setting up fonts-noto-mono (20171026-2) ...
# Setting up fonts-lato (2.0-2) ...
# Setting up libcupsfilters1:amd64 (1.20.2-0ubuntu3.1) ...
# Setting up libcupsimage2:amd64 (2.2.7-1ubuntu2.8) ...
# Setting up libjbig2dec0:amd64 (0.13-6) ...
# Setting up ruby-did-you-mean (1.2.0-2) ...
# Setting up t1utils (1.41-2) ...
# Setting up ruby-net-telnet (0.1.1-2) ...
# Setting up libijs-0.35:amd64 (0.35-13) ...
# Setting up rubygems-integration (1.11) ...
# Setting up libpotrace0 (1.14-2) ...
# Setting up javascript-common (11) ...
# Setting up ruby-minitest (5.10.3-1) ...
# Setting up libzzip-0-13:amd64 (0.13.62-3.1ubuntu0.18.04.1) ...
# Setting up libgs9:amd64 (9.26~dfsg+0-0ubuntu0.18.04.14) ...
# Setting up libtexluajit2:amd64 (2017.20170613.44572-8ubuntu0.1) ...
# Setting up fonts-lmodern (2.004.5-3) ...
# Setting up ruby-power-assert (0.3.0-1) ...
# Setting up texlive-binaries (2017.20170613.44572-8ubuntu0.1) ...
# update-alternatives: using /usr/bin/xdvi-xaw to provide /usr/bin/xdvi.bin (xdvi.bin) in auto mode
# update-alternatives: using /usr/bin/bibtex.original to provide /usr/bin/bibtex (bibtex) in auto mode
# Setting up texlive-base (2017.20180305-1) ...
# mktexlsr: Updating /var/lib/texmf/ls-R-TEXLIVEDIST...
# mktexlsr: Updating /var/lib/texmf/ls-R-TEXMFMAIN...
# mktexlsr: Updating /var/lib/texmf/ls-R...
# mktexlsr: Done.
# tl-paper: setting paper size for dvips to a4: /var/lib/texmf/dvips/config/config-paper.ps
# tl-paper: setting paper size for dvipdfmx to a4: /var/lib/texmf/dvipdfmx/dvipdfmx-paper.cfg
# tl-paper: setting paper size for xdvi to a4: /var/lib/texmf/xdvi/XDvi-paper
# tl-paper: setting paper size for pdftex to a4: /var/lib/texmf/tex/generic/config/pdftexconfig.tex
# Setting up texlive-fonts-recommended (2017.20180305-1) ...
# Setting up texlive-plain-generic (2017.20180305-2) ...
# Setting up texlive-latex-base (2017.20180305-1) ...
# Setting up lmodern (2.004.5-3) ...
# Setting up texlive-latex-recommended (2017.20180305-1) ...
# Setting up texlive-pictures (2017.20180305-1) ...
# Setting up tipa (2:1.3-20) ...
# Regenerating '/var/lib/texmf/fmtutil.cnf-DEBIAN'... done.
# Regenerating '/var/lib/texmf/fmtutil.cnf-TEXLIVEDIST'... done.
# update-fmtutil has updated the following file(s):
# 	/var/lib/texmf/fmtutil.cnf-DEBIAN
# 	/var/lib/texmf/fmtutil.cnf-TEXLIVEDIST
# If you want to activate the changes in the above file(s),
# you should run fmtutil-sys or fmtutil.
# Setting up texlive (2017.20180305-1) ...
# Setting up texlive-latex-extra (2017.20180305-2) ...
# Setting up texlive-xetex (2017.20180305-1) ...
# Setting up ruby2.5 (2.5.1-1ubuntu1.8) ...
# Setting up ruby (1:2.5.1) ...
# Setting up ruby-test-unit (3.2.5-1) ...
# Setting up rake (12.3.1-1ubuntu0.1) ...
# Setting up libruby2.5:amd64 (2.5.1-1ubuntu1.8) ...
# Processing triggers for mime-support (3.60ubuntu1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...
# Processing triggers for tex-common (6.09) ...
# Running updmap-sys. This may take some time... done.
# Running mktexlsr /var/lib/texmf ... done.
# Building format(s) --all.
# 	This may take some time... done.
# Collecting pypandoc
#   Downloading https://files.pythonhosted.org/packages/d6/b7/5050dc1769c8a93d3ec7c4bd55be161991c94b8b235f88bf7c764449e708/pypandoc-1.5.tar.gz
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pypandoc) (54.2.0)
# Requirement already satisfied: pip>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from pypandoc) (19.3.1)
# Requirement already satisfied: wheel>=0.25.0 in /usr/local/lib/python3.7/dist-packages (from pypandoc) (0.36.2)
# Building wheels for collected packages: pypandoc
#   Building wheel for pypandoc (setup.py) ... done
#   Created wheel for pypandoc: filename=pypandoc-1.5-cp37-none-any.whl size=17036 sha256=fdbf320f07cdc2cb07ef18846b4576071e809144d38af2ecb0daa0f31f34828a
#   Stored in directory: /root/.cache/pip/wheels/bb/7d/d6/2f9af55e800d37e42e546106bcbd36a86e24e725e303d17e04
# Successfully built pypandoc
# Installing collected packages: pypandoc
# Successfully installed pypandoc-1.5

# %%
# !jupyter nbconvert --to PDF "DP_Office_env.ipynb"
# Out:
# [NbConvertApp] Converting notebook DP_Office_env.ipynb to PDF
# [NbConvertApp] Writing 284861 bytes to ./notebook.tex
# [NbConvertApp] Building PDF
# [NbConvertApp] Running xelatex 3 times: [u'xelatex', u'./notebook.tex', '-quiet']
# [NbConvertApp] Running bibtex 1 time: [u'bibtex', u'./notebook']
# [NbConvertApp] WARNING | bibtex had problems, most likely because there were no citations
# [NbConvertApp] PDF successfully created
# [NbConvertApp] Writing 62517 bytes to DP_Office_env.pdf
